# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Downloads/List of Countries by Sugarcane Production.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %% [markdown]
# # Cleaning the data

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                   1264.303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace(".","")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205             75.167,5
# 1                     260721           4950000             70.393,5
# 2                      88287           1675215             73.459,1
# 3                   1264.303           1336575             65.442,2
# 4                     324219           1130820               57.879

# %%
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %% [markdown]
# # Renaming the columns

# %%
df.rename(columns= {"Production (Tons)":"Production(Tons)"},inplace=True)
df.rename(columns= {"Production per Person (Kg)":"Production_per_Person(Kg)"},inplace=True)
df.rename(columns= {"Acreage (Hectare)":"Acreage(Hectare)"},inplace=True)
df.rename(columns= {"Yield (Kg / Hectare)":"Yield(Kg / Hectare)"},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg / Hectare)
# 0                  3668.531         10226205             75167.5
# 1                    260721          4950000             70393.5
# 2                     88287          1675215             73459.1
# 3                  1264.303          1336575             65442.2
# 4                    324219          1130820               57879

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg / Hectare)
# 0         10226205             75167.5
# 1          4950000             70393.5
# 2          1675215             73459.1
# 3          1336575             65442.2
# 4          1130820               57879

# %% [markdown]
# # Checking for null values

# %%
df.isna().sum()
# Out:
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg / Hectare)          1
# dtype: int64

# %%
df=df.dropna().reset_index().drop('index',axis=1)

# %%
df
# Out:
#        Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0       Brazil  South America        768678382                  3668.531
# 1        India           Asia        348448000                    260721
# 2        China           Asia        123059739                     88287
# 3     Thailand           Asia         87468496                  1264.303
# 4     Pakistan           Asia         65450704                    324219
# ..         ...            ...              ...                       ...
# 97       Spain         Europe              394                         8
# 98     Lebanon           Asia               97                        16
# 99   Singapore           Asia               50                         9
# 100      Samoa        Oceania               12                         6
# 101      Syria           Asia                1                         0
#
#     Acreage(Hectare) Yield(Kg / Hectare)
# 0           10226205             75167.5
# ...

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg / Hectare)          102
# dtype: int64

# %% [markdown]
# # Correction of data types

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg / Hectare)          object
# dtype: object

# %%
df['Production(Tons)']=df['Production(Tons)'].astype('float')
df['Production_per_Person(Kg)']=df['Production_per_Person(Kg)'].astype('float')
df['Acreage(Hectare)']=df['Acreage(Hectare)'].astype('float')
df['Yield(Kg / Hectare)']=df['Yield(Kg / Hectare)'].astype('float')

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg / Hectare)          float64
# dtype: object

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg / Hectare)
# 0        10226205.0              75167.5
# 1         4950000.0              70393.5
# 2         1675215.0              73459.1
# 3         1336575.0              65442.2
# 4         1130820.0              57879.0

# %% [markdown]
# # How many countries produce sugarcane from each continent?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# Africa has the maximum no.of countries producing sugarcane

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg / Hectare)
# count           102.000000
# mean          52628.078431
# std           30504.676683
# min              10.000000
# 25%           29072.025000
# 50%           54108.950000
# 75%           73282.700000
# max          129049.300000

# %% [markdown]
# # Checking for outliers

# %%
plt.figure(figsize=(12,13))
plt.subplot(2,2,1)
sns.boxplot(df['Production(Tons)'])
plt.title('Production(Tons)')
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person(Kg)'])
plt.title('Production_per_Person(Kg)')
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(Hectare)'])
plt.title('Acreage(Hectare)')
plt.subplot(2,2,4)
sns.boxplot(df['Yield(Kg / Hectare)'])
plt.title('Yield(Kg / Hectare)')
# Out:
# Text(0.5, 1.0, 'Yield(Kg / Hectare)')

# %% [markdown]
# Here,Yield(Kg / Hectare) does not have any outliers

# %% [markdown]
# we have outliers in the data but outliers are required here as it shows the countries which has maximum production. And then we can see what are the reasons for outliers.

# %% [markdown]
# # Distribution of numerical columns

# %%
plt.figure(figsize=(10,13))
plt.subplot(2,2,1)
sns.distplot(df['Production(Tons)'])
plt.title('Production(Tons)')
plt.subplot(2,2,2)
sns.distplot(df['Production_per_Person(Kg)'])
plt.title('Production_per_Person(Kg)')
plt.subplot(2,2,3)
sns.distplot(df['Acreage(Hectare)'])
plt.title('Acreage(Hectare)')
plt.subplot(2,2,4)
sns.distplot(df['Yield(Kg / Hectare)'])
plt.title('Yield(Kg / Hectare)')
# Out:
# /var/folders/pq/ptcdv4ls0zd77lg_vn4vnxgw0000gn/T/ipykernel_1076/425358988.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production(Tons)'])
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/pq/ptcdv4ls0zd77lg_vn4vnxgw0000gn/T/ipykernel_1076/425358988.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg / Hectare)
# 0        10226205.0              75167.5
# 1         4950000.0              70393.5
# 2         1675215.0              73459.1
# 3         1336575.0              65442.2
# 4         1130820.0              57879.0

# %% [markdown]
# # Which country produces maximum sugarcane

# %%
df_new=df[['Country','Production(Tons)']]

# %%
df_new=df_new.set_index('Country')

# %%
ax=sns.barplot(data=df.head(10),x='Country',y='Production(Tons)')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Brazil'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'China'),
#  Text(3, 0, 'Thailand'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Colombia'),
#  Text(7, 0, 'Australia'),
#  Text(8, 0, 'Guatemala'),
#  Text(9, 0, 'United States of America')]

# %% [markdown]
# Brazil has maximum sugarcane production

# %% [markdown]
# # Top-10 country with highest land?

# %%
df_new=df.sort_values("Acreage(Hectare)",ascending=False)

# %%
ax=sns.barplot(data=df_new.head(10),x='Country',y='Acreage(Hectare)')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Brazil'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'China'),
#  Text(3, 0, 'Thailand'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Indonesia'),
#  Text(7, 0, 'Australia'),
#  Text(8, 0, 'Cuba'),
#  Text(9, 0, 'Colombia')]

# %% [markdown]
# # Which are the top-10 countries with highest yield per hectare?

# %%
df2=df.sort_values("Yield(Kg / Hectare)",ascending=False)
ax=sns.barplot(data=df2.head(10),x='Country',y='Yield(Kg / Hectare)')
ax.set_xticklabels(ax.get_xticklabels(),rotation=50)
# Out:
# [Text(0, 0, 'Guatemala'),
#  Text(1, 0, 'Senegal'),
#  Text(2, 0, 'Egypt'),
#  Text(3, 0, 'Peru'),
#  Text(4, 0, 'Malawi'),
#  Text(5, 0, 'Chad'),
#  Text(6, 0, 'Zambia'),
#  Text(7, 0, 'Burkina Faso'),
#  Text(8, 0, 'Swaziland'),
#  Text(9, 0, 'Nicaragua')]

# %% [markdown]
# So,Guatemala has highest yield per hectare

# %% [markdown]
# # Which are top-10 countries with highest production per person?

# %%
df3=df.sort_values("Production_per_Person(Kg)",ascending=False)
ax=sns.barplot(data=df3.head(10),x='Country',y='Production_per_Person(Kg)')
ax.set_xticklabels(ax.get_xticklabels(),rotation=80)
# Out:
# [Text(0, 0, 'Paraguay'),
#  Text(1, 0, 'Colombia'),
#  Text(2, 0, 'Trinidad and Tobago'),
#  Text(3, 0, 'Panama'),
#  Text(4, 0, 'Jamaica'),
#  Text(5, 0, 'Ecuador'),
#  Text(6, 0, 'Argentina'),
#  Text(7, 0, 'Dominican Republic'),
#  Text(8, 0, 'Mexico'),
#  Text(9, 0, 'Pakistan')]

# %% [markdown]
# So,paraguay has highest production_per_person(kg)

# %% [markdown]
# # Correlation

# %%
df_up=df.drop(['Country','Continent'],axis=1)

# %%
df_up.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg / Hectare)                0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg / Hectare)
# Production(Tons)                   0.997550             0.132812
# Production_per_Person(Kg)          0.012557             0.017999
# Acreage(Hectare)                   1.000000             0.113433
# Yield(Kg / Hectare)                0.113433             1.000000

# %% [markdown]
# So,here we can say that Acreage & Production(Tons) are highly correlated.

# %%
sns.heatmap(df_up.corr(),annot=True,cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# # Do,countries with highest land produce more sugarcane?

# %%
sns.scatterplot(data=df,x='Acreage(Hectare)',y='Production(Tons)',hue='Continent')
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# Yes,there is an overall rise in production with an increase in Acreage(Hectare) i.e land

# %% [markdown]
# # Do,the countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
sns.scatterplot(data=df,x='Yield(Kg / Hectare)',y='Production(Tons)',hue='Continent')
# Out:
# <Axes: xlabel='Yield(Kg / Hectare)', ylabel='Production(Tons)'>
